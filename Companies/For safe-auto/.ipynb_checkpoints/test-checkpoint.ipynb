# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %%
start = datetime.datetime(2018, 7, 1)
end = datetime.datetime.now()
df = web.DataReader("XOM", "morningstar", start, end)

# %%
print (df.head())
df['High'].plot()
df['Low'].plot()
plt.legend()
plt.show()
# Out:
#                    Close   High    Low   Open   Volume
# Symbol Date
# XOM    2018-07-02  81.76  82.13  81.32  81.89  9998318
#        2018-07-03  82.24  83.45  82.08  82.58  7197258
#        2018-07-04  82.24  82.24  82.24  82.24        0
#        2018-07-05  82.31  82.77  82.05  82.59  9035873
#        2018-07-06  82.33  82.70  81.66  81.96  7637116
